# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import bird_tree
#       3 print(bird_tree.predict(True,True,False,False,False))
#       4 #
#       5 # import binary_tree
#       6 # print(binary_tree.predict(True,True))
#
# ImportError: dynamic module does not define module export function (PyInit_bird_tree)
